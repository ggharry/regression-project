# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import log
from sklearn import linear_model
from statsmodels.formula.api import ols
from numpy import exp

# Set some Pandas options
pd.set_option('max_columns', 30)
pd.set_option('max_rows', 20)

# Default Plotting Size
mpl.rc("figure", figsize=(20, 8))

# Store data in a consistent place
DATA_DIR = 'data/'

# Default Plotting Size
mpl.rc("figure", figsize=(20, 8))

# %%
df = pd.read_csv(DATA_DIR + 'OnlineNewsPopularity.csv')

# %%
df.head()
# Out:
#                                                  url  timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...        731
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...        731
# 2  http://mashable.com/2013/01/07/apple-40-billio...        731
# 3  http://mashable.com/2013/01/07/astronaut-notre...        731
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/        731
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0              12               219         0.663594                 1
# 1               9               255         0.604743                 1
# 2               9               211         0.575130                 1
# 3               9               531         0.503788                 1
# 4              13              1072         0.415646                 1
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  num_videos  \
# ...

# %%
df.describe()
# Out:
#           timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# count  39644.000000    39644.000000      39644.000000     39644.000000
# mean     354.530471       10.398749        546.514731         0.548216
# std      214.163767        2.114037        471.107508         3.520708
# min        8.000000        2.000000          0.000000         0.000000
# 25%      164.000000        9.000000        246.000000         0.470870
# 50%      339.000000       10.000000        409.000000         0.539226
# 75%      542.000000       12.000000        716.000000         0.608696
# max      731.000000       23.000000       8474.000000       701.000000
#
#        n_non_stop_words  n_non_stop_unique_tokens     num_hrefs  \
# count      39644.000000              39644.000000  39644.000000
# mean           0.996469                  0.689175     10.883690
# std            5.231231                  3.264816     11.332017
# min            0.000000                  0.000000      0.000000
# ...

# %%
# df['log_average_token_length'] = log(df['average_token_length'])
# df['log_n_tokens_content'] = log(df['n_tokens_content'])

# df = df[np.isfinite(df['log_average_token_length'])]
# df = df[np.isfinite(df['log_n_tokens_content'])]

# plt.scatter(df['log_average_token_length'], df['log_n_tokens_content'])
# plt.show()

# %%
# plt.hist(df['shares'], bins=range(0, 30000, 100))
# plt.show()

# %%
# Make the model object
regr = linear_model.LinearRegression()

# %%
# Fit the data
length = len(df['data_channel_is_entertainment'].values)

predictors = [[df['num_imgs'].values[i], df['num_videos'].values[i]] for i in range(length)]

shares = df['data_channel_is_entertainment'].values

# %%
regr.fit(predictors, shares)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, normalize=False)

# %%
# Display the coefficients:
print regr.coef_
# Out:
# [ 0.00505052  0.01435946]

# %%
# Display our SSE:
print np.sum((regr.predict(predictors) - shares) ** 2)
# Out:
# 5606.24977477

# %%
# Scoring our model (closer to 1 is better!)
print regr.score(predictors, shares)
# Out:
# 0.0335365990446

# %%
results = ols('predictors ~ shares', df).fit()

# %%
# print(results.summary())
